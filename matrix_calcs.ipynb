# %% [markdown]
# To show that there exists $C_{\textup{cond}} > 1$ such that for all $q \in (0,1)$, any $V \in \mathcal{V}$ and any $V' \in \mathcal{A}_{b} \cup \mathcal{B}_{b}$ it holds that
# $$
#     \mathsf{Pr}_{V}(W_{6} = V') \geq \frac{\pi_{\textup{bal}}(V')}{C_{\textup{cond}}}
# $$
# requires the calculation of the 6th power of $Q_{\text{bal}}$. Next, in order to prove that for $V' \in \mathcal{A}_{f} \cup \mathcal{B}_{f}$,
# $$
#     \mathsf{Pr}_{V}(W_{i} = V' \text{ for some }i \in \{0,1,\dots,6\}) \geq \frac{\pi_{\textup{bal}}(V')}{C_{\textup{cond}}},
# $$
# we make use of the relation
# $$
#     \mathsf{Pr}_{V}(W_{i} = V' \text{ for some }i \in \{0,1,\dots,6\}) \geq \max\{\mathsf{Pr}_{V}(W_{5} = V'), \mathsf{Pr}_{V}(W_{6} = V')\}.
# $$
# Dealing with the second bound therefore additionally requires an analysis of the 5th power of $Q_{\text{bal}}$.

# %%
import sympy as sp

# %% [markdown]
# This Python script uses **SymPy**, a symbolic mathematics library, to symbolically construct the $18\times 18$ transition matrix $Q_{\textup{bal}}$. The matrix represents a Markov chain, where each element describes transition probabilities between states. The states are
# $$\{A_{b}^{(1)}, A_{b}^{(2)}, A_{b}^{(3)}, A_{f}^{(1)}, A_{f}^{(2)}, A_{f}^{(3)}, B_{b}^{(12)}, B_{b}^{(21)}, B_{b}^{(13)}, B_{b}^{(31)}, B_{b}^{(23)}, B_{b}^{(32)}, B_{f}^{(12)}, B_{f}^{(21)}, B_{f}^{(13)}, B_{f}^{(31)}, B_{f}^{(23)}, B_{f}^{(32)}\}$$
# in this order. The script proceeds to compute the 5th and 6th powers of $Q_{\textup{bal}}$ in order to lower bound transition probabilities.

# %%
q = sp.symbols('q')
Q_bal = [[0, q*sp.Rational(1,3), q*sp.Rational(1,3), 0, 0, 0, q*sp.Rational(1,6), q*sp.Rational(1,6), 0, 0, 0, 0, sp.Rational(1,2) - q*sp.Rational(1,2), sp.Rational(1,2) - q*sp.Rational(1,2), 0, 0, 0, 0],
    [q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, q*sp.Rational(1,6), q*sp.Rational(1,6), 0, 0, 0, 0, sp.Rational(1,2) - q*sp.Rational(1,2), sp.Rational(1,2) - q*sp.Rational(1,2), 0, 0],
    [q*sp.Rational(1,3), q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0, 0, q*sp.Rational(1,6), q*sp.Rational(1,6), 0, 0, 0, 0, sp.Rational(1,2) - q*sp.Rational(1,2), sp.Rational(1,2) - q*sp.Rational(1,2)],
    [0, q*sp.Rational(1,3), q*sp.Rational(1,3), 0, 0, 0, q*sp.Rational(1,6), q*sp.Rational(1,6), 0, 0, 0, 0, sp.Rational(1,2) - q*sp.Rational(1,2), sp.Rational(1,2) - q*sp.Rational(1,2), 0, 0, 0, 0],
    [q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, q*sp.Rational(1,6), q*sp.Rational(1,6), 0, 0, 0, 0, sp.Rational(1,2) - q*sp.Rational(1,2), sp.Rational(1,2) - q*sp.Rational(1,2), 0, 0],
    [q*sp.Rational(1,3), q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0, 0, q*sp.Rational(1,6), q*sp.Rational(1,6), 0, 0, 0, 0, sp.Rational(1,2) - q*sp.Rational(1,2), sp.Rational(1,2) - q*sp.Rational(1,2)],
    [q*sp.Rational(1,3), 0, 0, 0, 0, 1 - q, 0, q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0, 0],
    [q*sp.Rational(1,3), 0, 0, 0, 1 - q, 0, q*sp.Rational(1,3), 0, 0, 0, 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0],
    [0, q*sp.Rational(1,3), 0, 0, 0, 1 - q, 0, q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0, 0],
    [0, q*sp.Rational(1,3), 0, 1 - q, 0, 0, 0, 0, q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0],
    [0, 0, q*sp.Rational(1,3), 0, 1 - q, 0, q*sp.Rational(1,3), 0, 0, 0, 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0],
    [0, 0, q*sp.Rational(1,3), 1 - q, 0, 0, 0, 0, q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0],
    [q*sp.Rational(1,3), 0, 0, 0, 0, 1 - q, 0, q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0, 0],
    [q*sp.Rational(1,3), 0, 0, 0, 1 - q, 0, q*sp.Rational(1,3), 0, 0, 0, 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0],
    [0, q*sp.Rational(1,3), 0, 0, 0, 1 - q, 0, q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0, 0],
    [0, q*sp.Rational(1,3), 0, 1 - q, 0, 0, 0, 0, q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0],
    [0, 0, q*sp.Rational(1,3), 0, 1 - q, 0, q*sp.Rational(1,3), 0, 0, 0, 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0],
    [0, 0, q*sp.Rational(1,3), 1 - q, 0, 0, 0, 0, q*sp.Rational(1,3), 0, q*sp.Rational(1,3), 0, 0, 0, 0, 0, 0, 0]]
Q_bal = sp.Matrix(Q_bal)
Q_bal
#print(sp.latex(Q))
# Out:
# Matrix([
# [  0, q/3, q/3,     0,     0,     0, q/6, q/6,   0,   0,   0,   0, 1/2 - q/2, 1/2 - q/2,         0,         0,         0,         0],
# [q/3,   0, q/3,     0,     0,     0,   0,   0, q/6, q/6,   0,   0,         0,         0, 1/2 - q/2, 1/2 - q/2,         0,         0],
# [q/3, q/3,   0,     0,     0,     0,   0,   0,   0,   0, q/6, q/6,         0,         0,         0,         0, 1/2 - q/2, 1/2 - q/2],
# [  0, q/3, q/3,     0,     0,     0, q/6, q/6,   0,   0,   0,   0, 1/2 - q/2, 1/2 - q/2,         0,         0,         0,         0],
# [q/3,   0, q/3,     0,     0,     0,   0,   0, q/6, q/6,   0,   0,         0,         0, 1/2 - q/2, 1/2 - q/2,         0,         0],
# [q/3, q/3,   0,     0,     0,     0,   0,   0,   0,   0, q/6, q/6,         0,         0,         0,         0, 1/2 - q/2, 1/2 - q/2],
# [q/3,   0,   0,     0,     0, 1 - q,   0, q/3,   0, q/3,   0,   0,         0,         0,         0,         0,         0,         0],
# ...

# %%
Q_bal_5 = sp.simplify(Q_bal**5)
Q_bal_5
# Out:
# Matrix([
# ...

# %%
Q_bal_6 = sp.simplify(Q_bal**6)
Q_bal_6
# Out:
# Matrix([
# ...

# %% [markdown]
# Due to symmetry we can restrict our analysis to the columns representing $A_b^{(1)},A_f^{(1)},B_b^{(12)}$ and $B_f^{(12)}$ of the matrix $Q_\textup{bal}$, which corresponds to the 1st, 4th, 7th and 13th columns. We first deal with the backward edge states $A_b^{(1)}$, and $B_b^{(12)}$ and analyse the 1st and 7th column of $Q_\textup{bal}^6$.

# %%
Q_bal_6_sub_backward = Q_bal_6[:, [0, 6]].as_mutable()
Q_bal_6_sub_backward
#print(sp.latex(sub_Q_power_6))
# Out:
# Matrix([
# [        q*(132*q**5 - 496*q**4 + 690*q**3 - 405*q**2 + 81*q + 81)/486, q*(-832*q**5 + 3480*q**4 - 5832*q**3 + 4725*q**2 - 1782*q + 729)/5832],
# [ q*(628*q**5 - 2352*q**4 + 3690*q**3 - 3105*q**2 + 1377*q + 243)/2916,    q*(-640*q**5 + 2076*q**4 - 2295*q**3 + 918*q**2 - 81*q + 486)/5832],
# [ q*(628*q**5 - 2352*q**4 + 3690*q**3 - 3105*q**2 + 1377*q + 243)/2916,        q*(-64*q**5 + 236*q**4 - 377*q**3 + 333*q**2 - 153*q + 81)/648],
# [        q*(132*q**5 - 496*q**4 + 690*q**3 - 405*q**2 + 81*q + 81)/486, q*(-832*q**5 + 3480*q**4 - 5832*q**3 + 4725*q**2 - 1782*q + 729)/5832],
# [ q*(628*q**5 - 2352*q**4 + 3690*q**3 - 3105*q**2 + 1377*q + 243)/2916,    q*(-640*q**5 + 2076*q**4 - 2295*q**3 + 918*q**2 - 81*q + 486)/5832],
# [ q*(628*q**5 - 2352*q**4 + 3690*q**3 - 3105*q**2 + 1377*q + 243)/2916,        q*(-64*q**5 + 236*q**4 - 377*q**3 + 333*q**2 - 153*q + 81)/648],
# ...

# %% [markdown]
# Now we divide the first column of this sub matrix by $\pi_{\textup{bal}}(A_b^{(1)})$ and the second column by $\pi_{\textup{bal}}(B_b^{(12)})$, forgetting about constants, i.e., we divide every entry by $q$. What remains is a polynomial of degree $5$.

# %%
sub_Q6_backward_polynomial = Q_bal_6_sub_backward.copy()
for i in range(18):
    sub_Q6_backward_polynomial[i, 0] = sp.together(sub_Q6_backward_polynomial[i, 0] / q)
    sub_Q6_backward_polynomial[i, 1] = sp.together(sub_Q6_backward_polynomial[i, 1] / q)
sub_Q6_backward_polynomial
# Out:
# Matrix([
# [        (132*q**5 - 496*q**4 + 690*q**3 - 405*q**2 + 81*q + 81)/486, (-832*q**5 + 3480*q**4 - 5832*q**3 + 4725*q**2 - 1782*q + 729)/5832],
# [ (628*q**5 - 2352*q**4 + 3690*q**3 - 3105*q**2 + 1377*q + 243)/2916,    (-640*q**5 + 2076*q**4 - 2295*q**3 + 918*q**2 - 81*q + 486)/5832],
# [ (628*q**5 - 2352*q**4 + 3690*q**3 - 3105*q**2 + 1377*q + 243)/2916,        (-64*q**5 + 236*q**4 - 377*q**3 + 333*q**2 - 153*q + 81)/648],
# [        (132*q**5 - 496*q**4 + 690*q**3 - 405*q**2 + 81*q + 81)/486, (-832*q**5 + 3480*q**4 - 5832*q**3 + 4725*q**2 - 1782*q + 729)/5832],
# [ (628*q**5 - 2352*q**4 + 3690*q**3 - 3105*q**2 + 1377*q + 243)/2916,    (-640*q**5 + 2076*q**4 - 2295*q**3 + 918*q**2 - 81*q + 486)/5832],
# [ (628*q**5 - 2352*q**4 + 3690*q**3 - 3105*q**2 + 1377*q + 243)/2916,        (-64*q**5 + 236*q**4 - 377*q**3 + 333*q**2 - 153*q + 81)/648],
# ...

# %% [markdown]
# Next, we need to check if each polynomial is strictly larger than $0$ in the interval $[0,1]$. We plot all polynomials to convince the reader of this claim. This immediately implies that we can find a constant $C_1>0$ such that for each $V\in\mathcal{V}$ it holds that $\mathsf{Pr}_{V}(W_{6} = A_b^{(1)}) \geq \frac{\pi_{\textup{bal}}(A_b^{(1)})}{C_{1}}$ and $\mathsf{Pr}_{V}(W_{6} = B_b^{(12)}) \geq \frac{\pi_{\textup{bal}}(B_b^{(12)})}{C_{1}}$.

# %%
p = sp.plotting.plot(sub_Q6_backward_polynomial[0,0], (q, 0, 1), show=False)

for i in range(18):
    for j in range(2):
        if i>0 or j>0:
            p.extend(sp.plotting.plot(sub_Q6_backward_polynomial[i,j], (q, 0, 1), show=False))
p.ylim = (0, 0.3)
p.axis_center = (0, 0)
p.ylabel = "Polynomial(q)"
p.show()

# %% [markdown]
# To conclude the proof, a similar analysis must be performed for the two forward edge states $A_f^{(1)}$ and $B_f^{(12)}$.
# We need to consider both matrices $Q_\textup{bal}^5$ and $Q_\textup{bal}^6$ but can restrict our analysis to columns 4 and 13. We factorize the entries of the respective sub matrices of $Q_\textup{bal}^5$ and $Q_\textup{bal}^6$ by factoring out either $q$ or $1-q$. In the case of $Q_\textup{bal}^5$​, we factor out $q$ when transitioning from a state in $\mathcal{A}$ or $\mathcal{B}$ to another state within the same subset after five time steps; otherwise, we factor out $1−q$. For $Q_\textup{bal}^6$​, the roles of $q$ and $1−q$ are reversed.

# %%
sub_Q_5_forward = Q_bal_5[:, [3, 12]].as_mutable()

for i in range(6, 18):
    sub_Q_5_forward[i, 0], remainder = sp.div(sub_Q_5_forward[i, 0], 1 - q)
    if remainder != 0:
        print('Error')
    sub_Q_5_forward[i, 0] = sp.together(sub_Q_5_forward[i, 0])
    sub_Q_5_forward[i, 0] = (1 - q) * sub_Q_5_forward[i, 0]
for i in range(6):
    sub_Q_5_forward[i, 1], remainder = sp.div(sub_Q_5_forward[i, 1], 1 - q)
    if remainder != 0:
        print('Error')
    sub_Q_5_forward[i, 1] = sp.together(sub_Q_5_forward[i, 1])
    sub_Q_5_forward[i, 1] = (1 - q) * sub_Q_5_forward[i, 1]

sub_Q_5_forward
#print(sp.latex(sub_Q_power_5))
# Out:
# Matrix([
# [       q*(68*q**4 - 248*q**3 + 369*q**2 - 297*q + 108)/162,  (1 - q)*(92*q**4 - 330*q**3 + 459*q**2 - 270*q + 81)/324],
# [     q*(188*q**4 - 776*q**3 + 1263*q**2 - 999*q + 324)/324, (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [     q*(188*q**4 - 776*q**3 + 1263*q**2 - 999*q + 324)/324, (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [       q*(68*q**4 - 248*q**3 + 369*q**2 - 297*q + 108)/162,  (1 - q)*(92*q**4 - 330*q**3 + 459*q**2 - 270*q + 81)/324],
# [     q*(188*q**4 - 776*q**3 + 1263*q**2 - 999*q + 324)/324, (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [     q*(188*q**4 - 776*q**3 + 1263*q**2 - 999*q + 324)/324, (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [ (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/324,         q*(23*q**4 - 86*q**3 + 144*q**2 - 135*q + 54)/162],
# [ (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/324,         q*(23*q**4 - 86*q**3 + 144*q**2 - 135*q + 54)/162],
# ...

# %%
Q_bal_6_sub_forward = Q_bal_6[:, [3, 12]].as_mutable()

for i in range(6):
    Q_bal_6_sub_forward[i, 0], remainder = sp.div(Q_bal_6_sub_forward[i, 0], 1 - q)
    if remainder != 0:
        print('Error')
    Q_bal_6_sub_forward[i, 0] = sp.together(Q_bal_6_sub_forward[i, 0])
    Q_bal_6_sub_forward[i, 0] = (1 - q) * Q_bal_6_sub_forward[i, 0]
for i in range(6,18):
    Q_bal_6_sub_forward[i, 1], remainder = sp.div(Q_bal_6_sub_forward[i, 1], 1 - q)
    if remainder != 0:
        print('Error')
    Q_bal_6_sub_forward[i, 1] = sp.together(Q_bal_6_sub_forward[i, 1])
    Q_bal_6_sub_forward[i, 1] = (1 - q) * Q_bal_6_sub_forward[i, 1]

Q_bal_6_sub_forward
#print(sp.latex(sub_Q_power_6))
# Out:
# Matrix([
# [(1 - q)*(-704*q**5 + 2544*q**4 - 3474*q**3 + 2187*q**2 - 648*q + 243)/972,       q*(-256*q**5 + 1084*q**4 - 1935*q**3 + 1971*q**2 - 1269*q + 405)/972],
# [(1 - q)*(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,       q*(-256*q**5 + 1260*q**4 - 2555*q**3 + 2703*q**2 - 1557*q + 405)/648],
# [(1 - q)*(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,       q*(-256*q**5 + 1260*q**4 - 2555*q**3 + 2703*q**2 - 1557*q + 405)/648],
# [(1 - q)*(-704*q**5 + 2544*q**4 - 3474*q**3 + 2187*q**2 - 648*q + 243)/972,       q*(-256*q**5 + 1084*q**4 - 1935*q**3 + 1971*q**2 - 1269*q + 405)/972],
# [(1 - q)*(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,       q*(-256*q**5 + 1260*q**4 - 2555*q**3 + 2703*q**2 - 1557*q + 405)/648],
# [(1 - q)*(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,       q*(-256*q**5 + 1260*q**4 - 2555*q**3 + 2703*q**2 - 1557*q + 405)/648],
# ...

# %% [markdown]
# Since for $V' \in\mathcal{A}_f \cup \mathcal{B}_f$ it holds that $\pi_\text{Bal}(V') = O(1-q)$, we lower bound each entry of the maximum (to be understood entrywise) of the sub matrices of $Q_\textup{Bal}^5$ and $Q_\textup{Bal}^6$ with the respective entry that contains the factor $1-q$.

# %%
lower_bound_max_Q_bal_5_Q_bal_6_forward = sp.Matrix.hstack(sp.Matrix.vstack(Q_bal_6_sub_forward[0:6, 0], sub_Q_5_forward[6:18, 0]), sp.Matrix.vstack(sub_Q_5_forward[0:6, 1], Q_bal_6_sub_forward[6:18, 1]))
lower_bound_max_Q_bal_5_Q_bal_6_forward
#print(sp.latex(lower_bound_matrix))
# Out:
# Matrix([
# [(1 - q)*(-704*q**5 + 2544*q**4 - 3474*q**3 + 2187*q**2 - 648*q + 243)/972,                   (1 - q)*(92*q**4 - 330*q**3 + 459*q**2 - 270*q + 81)/324],
# [(1 - q)*(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,                  (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [(1 - q)*(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,                  (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [(1 - q)*(-704*q**5 + 2544*q**4 - 3474*q**3 + 2187*q**2 - 648*q + 243)/972,                   (1 - q)*(92*q**4 - 330*q**3 + 459*q**2 - 270*q + 81)/324],
# [(1 - q)*(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,                  (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [(1 - q)*(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,                  (1 - q)*(164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# ...

# %% [markdown]
# Now we can repeat the analysis performed for the backward edge state case for the forward edge state case.

# %%
lower_bound_max_Q_bal_5_Q_bal_6_forward_polynomial = lower_bound_max_Q_bal_5_Q_bal_6_forward.copy()
for i in range(18):
    lower_bound_max_Q_bal_5_Q_bal_6_forward_polynomial[i, 0] = sp.together(lower_bound_max_Q_bal_5_Q_bal_6_forward_polynomial[i, 0] / (1 - q))
    lower_bound_max_Q_bal_5_Q_bal_6_forward_polynomial[i, 1] = sp.together(lower_bound_max_Q_bal_5_Q_bal_6_forward_polynomial[i, 1] / (1 - q))

lower_bound_max_Q_bal_5_Q_bal_6_forward_polynomial
# Out:
# Matrix([
# [(-704*q**5 + 2544*q**4 - 3474*q**3 + 2187*q**2 - 648*q + 243)/972,                   (92*q**4 - 330*q**3 + 459*q**2 - 270*q + 81)/324],
# [(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,                  (164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,                  (164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [(-704*q**5 + 2544*q**4 - 3474*q**3 + 2187*q**2 - 648*q + 243)/972,                   (92*q**4 - 330*q**3 + 459*q**2 - 270*q + 81)/324],
# [(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,                  (164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [(-448*q**5 + 1712*q**4 - 2682*q**3 + 2151*q**2 - 864*q + 243)/648,                  (164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/648],
# [                (164*q**4 - 438*q**3 + 405*q**2 - 162*q + 81)/324,        (-76*q**5 + 258*q**4 - 329*q**3 + 201*q**2 - 63*q + 27)/216],
# ...

# %%
p = sp.plotting.plot(lower_bound_max_Q_bal_5_Q_bal_6_forward_polynomial[0,0], (q, 0, 1), show=False)

for i in range(18):
    for j in range(2):
        if i>0 or j>0:
            p.extend(sp.plotting.plot(lower_bound_max_Q_bal_5_Q_bal_6_forward_polynomial[i,j], (q, 0, 1), show=False))
p.ylim = (0, 0.5)
p.axis_center = (0, 0)
p.ylabel = "Polynomial(q)"
p.show()
